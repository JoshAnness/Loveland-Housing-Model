# %% [markdown]
# # {ML vs My Mom - Housing Model}📝
#
# ![Banner](./assets/banner.jpeg)

# %% [markdown]
# ## Topic
# *What problem are you (or your stakeholder) trying to address?*
# 📝 <!-- Answer Below -->
#
# People are always either trying to sell a house or buy a house, can a machine learning model accurately predict the price? This predicted price is not only useful to potenital buyers/sellers but can be useful to those in the real estate business like real estate agents and property developers.

# %% [markdown]
# ## Project Question
# *What specific question are you seeking to answer with this project?*
# *This is not the same as the questions you ask to limit the scope of the project.*
# 📝 <!-- Answer Below -->
#
# Can my model more accurately predict the price of houses than a human with good knowledge of the area (my mom)?

# %% [markdown]
# ## What would an answer look like?
# *What is your hypothesized answer to your question?*
# 📝 <!-- Answer Below -->
#
# I will take a random sample of houses for my model to predict and my mom to predict (she will be able to use all available info) and compare to see who is more accurate. I think my mom will probably be more accurate.

# %% [markdown]
# ## Data Sources
# *What 3 data sources have you identified for this project?*
# *How are you going to relate these datasets?*
# 📝 <!-- Answer Below -->
#
# Scraping Zillow

# %% [markdown]
# ## Approach and Analysis
# *What is your approach to answering your project question?*
# *How will you use the identified data to answer your project question?*
# 📝 <!-- Start Discussing the project here; you can add as many code cells as you need -->
#
# I am planning on creating a regression model based on the Zillow dataset and features I am able to scrape.

# %%
import json
import time
import pandas as pd
import http.client

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns


mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
plt.style.use("bmh")
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Data Scraping
# My Zillow query only looks at houses sold in the Loveland, OH area in the past year (3/26/2022-2/36/2023)

# %%
statusType = []
soldPrice = []
unformattedPrice = []
address = []
addressStreet = []
addressCity = []
addressState = []
addressZipcode = []
beds = []
baths = []
area = []
isZillowOwned = []
variableData = []
hdpData = []
latitude = []
longitude = []
price = []
dateSold = []
homeType = []
homeStatus = []
zestimate = []
rentZestimate = []
priceForHDP = []
currency = []
country = []
taxAssessedValue = []
lotAreaValue = []
lotAreaUnit = []
brokerName = []

def getResponse(page):
  url = f"https://www.zillow.com/search/GetSearchPageState.htm?searchQueryState=%7B%22pagination%22%3A%7B%22currentPage%22%3A{page}%7D%2C%22usersSearchTerm%22%3A%22Loveland%2C%20OH%22%2C%22mapBounds%22%3A%7B%22west%22%3A-84.37974306982422%2C%22east%22%3A-84.10302493017578%2C%22south%22%3A39.152149232712055%2C%22north%22%3A39.36534736841241%7D%2C%22mapZoom%22%3A12%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A5710%2C%22regionType%22%3A6%7D%5D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22doz%22%3A%7B%22value%22%3A%2212m%22%7D%2C%22isCondo%22%3A%7B%22value%22%3Afalse%7D%2C%22isForSaleForeclosure%22%3A%7B%22value%22%3Afalse%7D%2C%22isApartment%22%3A%7B%22value%22%3Afalse%7D%2C%22isMultiFamily%22%3A%7B%22value%22%3Afalse%7D%2C%22isAllHomes%22%3A%7B%22value%22%3Atrue%7D%2C%22sortSelection%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22isAuction%22%3A%7B%22value%22%3Afalse%7D%2C%22isNewConstruction%22%3A%7B%22value%22%3Afalse%7D%2C%22isRecentlySold%22%3A%7B%22value%22%3Atrue%7D%2C%22isLotLand%22%3A%7B%22value%22%3Afalse%7D%2C%22isTownhouse%22%3A%7B%22value%22%3Afalse%7D%2C%22isMiddleSchool%22%3A%7B%22value%22%3Afalse%7D%2C%22isHighSchool%22%3A%7B%22value%22%3Afalse%7D%2C%22includeUnratedSchools%22%3A%7B%22value%22%3Afalse%7D%2C%22isManufactured%22%3A%7B%22value%22%3Afalse%7D%2C%22isForSaleByOwner%22%3A%7B%22value%22%3Afalse%7D%2C%22isComingSoon%22%3A%7B%22value%22%3Afalse%7D%2C%22isPublicSchool%22%3A%7B%22value%22%3Afalse%7D%2C%22isPrivateSchool%22%3A%7B%22value%22%3Afalse%7D%2C%22isApartmentOrCondo%22%3A%7B%22value%22%3Afalse%7D%2C%22isElementarySchool%22%3A%7B%22value%22%3Afalse%7D%2C%22isForSaleByAgent%22%3A%7B%22value%22%3Afalse%7D%2C%22isCharterSchool%22%3A%7B%22value%22%3Afalse%7D%2C%22greatSchoolsRating%22%3A%7B%22min%22%3A%221%22%7D%7D%2C%22isListVisible%22%3Atrue%7D&wants={{%22cat1%22:[%22listResults%22]}}&requestId=2"

  conn = http.client.HTTPSConnection("www.zillow.com")

  payload={}
  headers = {
    'Cookie': 'x-amz-continuous-deployment-state=AYABeHEN0tqCsWupmgl3%2F5ovG78APgACAAFEAB1kM2Jsa2Q0azB3azlvai5jbG91ZGZyb250Lm5ldAABRwAVRzAxMTE2MjczQzlQQzdZU1JDTVBHAAEAAkNEABpDb29raWUAAACAAAAADG%2F52OaQfNIJt5gr7wAwa8ksg4xl78oKkXFQzgMai7yix49fWvQdzMBOStxRZ0nNBNdkcp0yAUNlFIZtgepnAgAAAAAMAAQAAAAAAAAAAAAAAAAAALGapE1G2GC1faDJGo+NNaX%2F%2F%2F%2F%2FAAAAAQAAAAAAAAAAAAAAAQAAAAxE9IK0h9G6jGBvr5xywc2FYfQD9+myuKPFg1MgQD9+myuKPFg1Mg==; search=6|1682459771554%7Crect%3D39.36534736841241%252C-84.10302493017578%252C39.152149232712055%252C-84.37974306982422%26rid%3D5710%26disp%3Dmap%26mdm%3Dauto%26p%3D1%26z%3D1%26listPriceActive%3D1%26days%3D12m%26type%3Dhouse%26fs%3D0%26fr%3D0%26mmm%3D0%26rs%3D1%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%26featuredMultiFamilyBuilding%3D0%26commuteMode%3Ddriving%26commuteTimeOfDay%3Dnow%09%09%09%09%09%09%09%09; zgsession=1|e42fe483-86c7-4941-a44a-035f9ad782e7; zguid=24|%2423d0665d-1a19-4c83-95e5-30ab8f8ec133; AWSALB=7o8QDvkzOEBfwgmsA8eFXbIz1xIWMhxgOu0raIK0MDqHFCnifRfm9ictKJBlnRbacFusneyZJ4AduduIXRQEGjgvn1b/8WcE9Sa3zUAmkNpWqTSZPidQJZyNEvnz; AWSALBCORS=7o8QDvkzOEBfwgmsA8eFXbIz1xIWMhxgOu0raIK0MDqHFCnifRfm9ictKJBlnRbacFusneyZJ4AduduIXRQEGjgvn1b/8WcE9Sa3zUAmkNpWqTSZPidQJZyNEvnz; JSESSIONID=B27F9E1F606458A6EEBC079ECEA1DFB6'
  }

  conn.request("GET", url, payload, headers)
  res = conn.getresponse()
  data = res.read()
  data = data.decode("utf-8")
  json_obj = json.loads(data)
  return json_obj

def getData(json_obj):
  data = [x for x in json_obj["cat1"]["searchResults"]['listResults']]
      
  for d in data:
    statusType.append(d['statusType'] if 'statusType' in d else None)
    soldPrice.append(d['soldPrice'] if 'soldPrice' in d else None)
    unformattedPrice.append(d['unformattedPrice'] if 'unformattedPrice' in d else None)
    address.append(d['address'] if 'address' in d else None)
    addressStreet.append(d['addressStreet'] if 'addressStreet' in d else None)
    addressCity.append(d['addressCity'] if 'addressCity' in d else None)
    addressState.append(d['addressState'] if 'addressState' in d else None)
    addressZipcode.append(d['addressZipcode'] if 'addressZipcode' in d else None)
    beds.append(d['beds'] if 'beds' in d else None)
    baths.append(d['baths'] if 'baths' in d else None)
    area.append(d['area'] if 'area' in d else None)
    isZillowOwned.append(d['isZillowOwned'] if 'isZillowOwned' in d else None)
    variableData.append(d['variableData'] if 'variableData' in d else None)
    hdpData.append(d['hdpData'] if 'hdpData' in d else None)
    latitude.append(d['hdpData']['homeInfo']['latitude'] if 'hdpData' in d and 'homeInfo' in d['hdpData'] and 'latitude' in d['hdpData']['homeInfo'] else None)
    longitude.append(d['hdpData']['homeInfo']['longitude'] if 'hdpData' in d and 'homeInfo' in d['hdpData'] and 'longitude' in d['hdpData']['homeInfo'] else None)
    price.append(d['hdpData']['homeInfo']['price'] if 'hdpData' in d and 'homeInfo' in d['hdpData'] and 'price' in d['hdpData']['homeInfo'] else None)
    dateSold.append(d['hdpData']['homeInfo']['dateSold'] if 'hdpData' in d and 'homeInfo' in d['hdpData'] and 'dateSold' in d['hdpData']['homeInfo'] else None)
    homeType.append(d['hdpData']['homeInfo']['homeType'] if 'hdpData' in d and 'homeInfo' in d['hdpData'] and 'homeType' in d['hdpData']['homeInfo'] else None)
    homeStatus.append(d['hdpData']['homeInfo']['homeStatus'] if 'hdpData' in d and 'homeInfo' in d['hdpData'] and 'homeStatus' in d['hdpData']['homeInfo'] else None)
    zestimate.append(d['hdpData']['homeInfo']['zestimate'] if 'hdpData' in d and 'homeInfo' in d['hdpData'] and 'zestimate' in d['hdpData']['homeInfo'] else None)
    rentZestimate.append(d['hdpData']['homeInfo']['rentZestimate'] if 'hdpData' in d and 'homeInfo' in d['hdpData'] and 'rentZestimate' in d['hdpData']['homeInfo'] else None)  
    priceForHDP.append(d['hdpData']['homeInfo']['priceForHDP'] if 'hdpData' in d and 'homeInfo' in d['hdpData'] and 'priceForHDP' in d['hdpData']['homeInfo'] else None)
    currency.append(d['hdpData']['homeInfo']['currency'] if 'hdpData' in d and 'homeInfo' in d['hdpData'] and 'currency' in d['hdpData']['homeInfo'] else None)
    country.append(d['hdpData']['homeInfo']['country'] if 'hdpData' in d and 'homeInfo' in d['hdpData'] and 'country' in d['hdpData']['homeInfo'] else None)
    taxAssessedValue.append(d['hdpData']['homeInfo']['taxAssessedValue'] if 'hdpData' in d and 'homeInfo' in d['hdpData'] and 'taxAssessedValue' in d['hdpData']['homeInfo'] else None)
    lotAreaValue.append(d['hdpData']['homeInfo']['lotAreaValue'] if 'hdpData' in d and 'homeInfo' in d['hdpData'] and 'lotAreaValue' in d['hdpData']['homeInfo'] else None)
    lotAreaUnit.append(d['hdpData']['homeInfo']['lotAreaUnit'] if 'hdpData' in d and 'homeInfo' in d['hdpData'] and 'lotAreaUnit' in d['hdpData']['homeInfo'] else None)
    brokerName.append(d['brokerName'] if 'brokerName' in d else None)

# %%
# Run initially to get the total pages
url = f"https://www.zillow.com/search/GetSearchPageState.htm?searchQueryState=%7B%22pagination%22%3A%7B%22currentPage%22%3A1%7D%2C%22usersSearchTerm%22%3A%22Loveland%2C%20OH%22%2C%22mapBounds%22%3A%7B%22west%22%3A-84.37974306982422%2C%22east%22%3A-84.10302493017578%2C%22south%22%3A39.152149232712055%2C%22north%22%3A39.36534736841241%7D%2C%22mapZoom%22%3A12%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A5710%2C%22regionType%22%3A6%7D%5D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22doz%22%3A%7B%22value%22%3A%2212m%22%7D%2C%22isCondo%22%3A%7B%22value%22%3Afalse%7D%2C%22isForSaleForeclosure%22%3A%7B%22value%22%3Afalse%7D%2C%22isApartment%22%3A%7B%22value%22%3Afalse%7D%2C%22isMultiFamily%22%3A%7B%22value%22%3Afalse%7D%2C%22isAllHomes%22%3A%7B%22value%22%3Atrue%7D%2C%22sortSelection%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22isAuction%22%3A%7B%22value%22%3Afalse%7D%2C%22isNewConstruction%22%3A%7B%22value%22%3Afalse%7D%2C%22isRecentlySold%22%3A%7B%22value%22%3Atrue%7D%2C%22isLotLand%22%3A%7B%22value%22%3Afalse%7D%2C%22isTownhouse%22%3A%7B%22value%22%3Afalse%7D%2C%22isMiddleSchool%22%3A%7B%22value%22%3Afalse%7D%2C%22isHighSchool%22%3A%7B%22value%22%3Afalse%7D%2C%22includeUnratedSchools%22%3A%7B%22value%22%3Afalse%7D%2C%22isManufactured%22%3A%7B%22value%22%3Afalse%7D%2C%22isForSaleByOwner%22%3A%7B%22value%22%3Afalse%7D%2C%22isComingSoon%22%3A%7B%22value%22%3Afalse%7D%2C%22isPublicSchool%22%3A%7B%22value%22%3Afalse%7D%2C%22isPrivateSchool%22%3A%7B%22value%22%3Afalse%7D%2C%22isApartmentOrCondo%22%3A%7B%22value%22%3Afalse%7D%2C%22isElementarySchool%22%3A%7B%22value%22%3Afalse%7D%2C%22isForSaleByAgent%22%3A%7B%22value%22%3Afalse%7D%2C%22isCharterSchool%22%3A%7B%22value%22%3Afalse%7D%2C%22greatSchoolsRating%22%3A%7B%22min%22%3A%221%22%7D%7D%2C%22isListVisible%22%3Atrue%7D&wants={{%22cat1%22:[%22listResults%22]}}&requestId=2"

conn = http.client.HTTPSConnection("www.zillow.com")

payload={}
headers = {
'Cookie': 'x-amz-continuous-deployment-state=AYABeHEN0tqCsWupmgl3%2F5ovG78APgACAAFEAB1kM2Jsa2Q0azB3azlvai5jbG91ZGZyb250Lm5ldAABRwAVRzAxMTE2MjczQzlQQzdZU1JDTVBHAAEAAkNEABpDb29raWUAAACAAAAADG%2F52OaQfNIJt5gr7wAwa8ksg4xl78oKkXFQzgMai7yix49fWvQdzMBOStxRZ0nNBNdkcp0yAUNlFIZtgepnAgAAAAAMAAQAAAAAAAAAAAAAAAAAALGapE1G2GC1faDJGo+NNaX%2F%2F%2F%2F%2FAAAAAQAAAAAAAAAAAAAAAQAAAAxE9IK0h9G6jGBvr5xywc2FYfQD9+myuKPFg1MgQD9+myuKPFg1Mg==; search=6|1682459771554%7Crect%3D39.36534736841241%252C-84.10302493017578%252C39.152149232712055%252C-84.37974306982422%26rid%3D5710%26disp%3Dmap%26mdm%3Dauto%26p%3D1%26z%3D1%26listPriceActive%3D1%26days%3D12m%26type%3Dhouse%26fs%3D0%26fr%3D0%26mmm%3D0%26rs%3D1%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%26featuredMultiFamilyBuilding%3D0%26commuteMode%3Ddriving%26commuteTimeOfDay%3Dnow%09%09%09%09%09%09%09%09; zgsession=1|e42fe483-86c7-4941-a44a-035f9ad782e7; zguid=24|%2423d0665d-1a19-4c83-95e5-30ab8f8ec133; AWSALB=7o8QDvkzOEBfwgmsA8eFXbIz1xIWMhxgOu0raIK0MDqHFCnifRfm9ictKJBlnRbacFusneyZJ4AduduIXRQEGjgvn1b/8WcE9Sa3zUAmkNpWqTSZPidQJZyNEvnz; AWSALBCORS=7o8QDvkzOEBfwgmsA8eFXbIz1xIWMhxgOu0raIK0MDqHFCnifRfm9ictKJBlnRbacFusneyZJ4AduduIXRQEGjgvn1b/8WcE9Sa3zUAmkNpWqTSZPidQJZyNEvnz; JSESSIONID=B27F9E1F606458A6EEBC079ECEA1DFB6'
}

conn.request("GET", url, payload, headers)
res = conn.getresponse()
data = res.read()
data = data.decode("utf-8")
json_obj = json.loads(data)

total_pages = json_obj.get('cat1', dict()).get('searchList', dict()).get('totalPages')

print(total_pages)
# Out:
# 20

# %%
for page in range(1, total_pages+1):
    json_obj = getResponse(page)
    print(json_obj)
    getData(json_obj)
    time.sleep(200)
# Out:
# {'user': {'isLoggedIn': False, 'email': '', 'displayName': '', 'hasHousingConnectorPermission': False, 'savedHomesCount': 0, 'personalizedSearchGaDataTag': None, 'personalizedSearchTraceID': '6420ee7f90a0d50921ce7514cb0d1e44', 'guid': '23d0665d-1a19-4c83-95e5-30ab8f8ec133', 'zuid': '', 'isBot': False, 'userSpecializedSEORegion': False}, 'mapState': {'customRegionPolygonWkt': None, 'schoolPolygonWkt': None, 'isCurrentLocationSearch': False, 'userPosition': {'lat': None, 'lon': None}}, 'regionState': {'regionInfo': [{'regionType': 6, 'regionId': 5710, 'regionName': 'Loveland', 'displayName': 'Loveland OH', 'isPointRegion': False}], 'regionBounds': {'north': 39.320723, 'east': -84.158661, 'south': 39.196881, 'west': -84.324107}}, 'searchPageSeoObject': {'baseUrl': '/loveland-oh/sold/', 'windowTitle': 'Recently Sold Homes in Loveland OH - 925 Transactions | Zillow', 'metaDescription': 'Browse data on the 925 recent real estate transactions in Loveland OH. Great for discovering comps, sales history, photos, and more.'}, 'requestId': 2, 'cat1': {'searchResults': {'listResults': [{'zpid': '51261260', 'id': '51261260', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/7dac073f4e43107d73dd3cfd036f1c62-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/7dac073f4e43107d73dd3cfd036f1c62-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/6533-Covey-Ct-Loveland-OH-45140/51261260_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$381,000', 'unformattedPrice': 381000, 'address': '6533 Covey Ct, Loveland, OH 45140', 'addressStreet': '6533 Covey Ct', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': 3, 'baths': 3.0, 'area': 1919, 'latLong': {'latitude': 39.241352, 'longitude': -84.27033}, 'isZillowOwned': False, 'variableData': {'type': 'RECENTLY_SOLD', 'text': 'Sold 03/24/2023'}, 'badgeInfo': None, 'hdpData': {'homeInfo': {'zpid': 51261260, 'streetAddress': '6533 Covey Ct', 'zipcode': '45140', 'city': 'Loveland', 'state': 'OH', 'latitude': 39.241352, 'longitude': -84.27033, 'price': 381000.0, 'dateSold': 1679641200000, 'bathrooms': 3.0, 'bedrooms': 3.0, 'livingArea': 1919.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'RECENTLY_SOLD', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'zestimate': 281500, 'rentZestimate': 2298, 'listing_sub_type': {}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'RECENTLY_SOLD', 'priceForHDP': 381000.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 192400.0, 'lotAreaValue': 0.9199999999999999, 'lotAreaUnit': 'acres'}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'RecentlySold', 'sgapt': 'RecentChange', 'zestimate': 281500, 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'info3String': 'https://photos.zillowstatic.com/fp/24a93a3e8104474bd1cf1ccae9e2ff31-zillow_web_48_23.jpg', 'brokerName': 'Keller Williams Pinnacle Group', 'hasAdditionalAttributions': True, 'isFeaturedListing': False, 'availabilityDate': None, 'list': True, 'relaxed': False}, {'zpid': '2059539477', 'id': '2059539477', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/0f54e536a45f73e29e5d810cd60a04ad-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/0f54e536a45f73e29e5d810cd60a04ad-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/833-Miami-Ridge-Dr-Loveland-OH-45140/2059539477_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$627,500', 'unformattedPrice': 627500, 'address': '833 Miami Ridge Dr, Loveland, OH 45140', 'addressStreet': '833 Miami Ridge Dr', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'i ...
# {'user': {'isLoggedIn': False, 'email': '', 'displayName': '', 'hasHousingConnectorPermission': False, 'savedHomesCount': 0, 'personalizedSearchGaDataTag': None, 'personalizedSearchTraceID': '6420ef486613a0f429e4e61de80f9bb0', 'guid': '23d0665d-1a19-4c83-95e5-30ab8f8ec133', 'zuid': '', 'isBot': False, 'userSpecializedSEORegion': False}, 'mapState': {'customRegionPolygonWkt': None, 'schoolPolygonWkt': None, 'isCurrentLocationSearch': False, 'userPosition': {'lat': None, 'lon': None}}, 'regionState': {'regionInfo': [{'regionType': 6, 'regionId': 5710, 'regionName': 'Loveland', 'displayName': 'Loveland OH', 'isPointRegion': False}], 'regionBounds': {'north': 39.320723, 'east': -84.158661, 'south': 39.196881, 'west': -84.324107}}, 'searchPageSeoObject': {'baseUrl': '/loveland-oh/sold/2_p/', 'windowTitle': 'Recently Sold Homes in Loveland OH - 925 Transactions | Zillow', 'metaDescription': 'Browse data on the 925 recent real estate transactions in Loveland OH. Great for discovering comps, sales history, photos, and more.'}, 'requestId': 2, 'cat1': {'searchResults': {'listResults': [{'zpid': '110617464', 'id': '110617464', 'providerListingId': None, 'streetViewMetadataURL': 'https://maps.googleapis.com/maps/api/streetview/metadata?location=39.225311279296875,-84.18925476074219&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=KGulUpSkZKCgyXu-3ubUTrRQ4kc=', 'streetViewURL': 'https://maps.googleapis.com/maps/api/streetview?size=575x242&location=39.225311279296875,-84.18925476074219&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=0DzlxZ-Oln8KiFH9erWxyaJdFL8=', 'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=39.225311279296875,-84.18925476074219&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=AAP4xzG9MXgFVelpQJYkOBUBYlY=', 'carouselPhotos': None, 'detailUrl': 'https://www.zillow.com/homedetails/State-Route-28-Loveland-OH-45140/110617464_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$680,425', 'unformattedPrice': 680425, 'address': 'State Route 28, Loveland, OH 45140', 'addressStreet': 'State Route 28', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': 3, 'baths': 1.0, 'area': 1564, 'latLong': {'latitude': 39.22531, 'longitude': -84.189255}, 'isZillowOwned': False, 'variableData': {'type': 'RECENTLY_SOLD', 'text': 'Sold 02/27/2023'}, 'badgeInfo': None, 'hdpData': {'homeInfo': {'zpid': 110617464, 'streetAddress': 'State Route 28', 'zipcode': '45140', 'city': 'Loveland', 'state': 'OH', 'latitude': 39.22531, 'longitude': -84.189255, 'price': 680425.0, 'dateSold': 1677484800000, 'bathrooms': 1.0, 'bedrooms': 3.0, 'livingArea': 1564.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'RECENTLY_SOLD', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'listing_sub_type': {}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'RECENTLY_SOLD', 'priceForHDP': 680425.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 15400.0, 'lotAreaValue': 0.5639807162534435, 'lotAreaUnit': 'acres'}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'RecentlySold', 'sgapt': 'Unknown Listed By', 'zestimate': None, 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'hasAdditionalAttributions': False, 'isFeaturedListing': False, 'availabilityDate': None, 'list': True, 'relaxed': False}, {'zpid': '34421345', 'id': '34421345', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/6c3f22ee62b5ff6376b2146933d14cff-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/6c3f22ee62b5ff6376b2146933d14cff-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/1837-Lemontree-Ln-Loveland-OH-45140/34421345_zpi ...
# {'user': {'isLoggedIn': False, 'email': '', 'displayName': '', 'hasHousingConnectorPermission': False, 'savedHomesCount': 0, 'personalizedSearchGaDataTag': None, 'personalizedSearchTraceID': '6420f01090a2126f7a2a59db1f34b8d7', 'guid': '23d0665d-1a19-4c83-95e5-30ab8f8ec133', 'zuid': '', 'isBot': False, 'userSpecializedSEORegion': False}, 'mapState': {'customRegionPolygonWkt': None, 'schoolPolygonWkt': None, 'isCurrentLocationSearch': False, 'userPosition': {'lat': None, 'lon': None}}, 'regionState': {'regionInfo': [{'regionType': 6, 'regionId': 5710, 'regionName': 'Loveland', 'displayName': 'Loveland OH', 'isPointRegion': False}], 'regionBounds': {'north': 39.320723, 'east': -84.158661, 'south': 39.196881, 'west': -84.324107}}, 'searchPageSeoObject': {'baseUrl': '/loveland-oh/sold/3_p/', 'windowTitle': 'Recently Sold Homes in Loveland OH - 925 Transactions | Zillow', 'metaDescription': 'Browse data on the 925 recent real estate transactions in Loveland OH. Great for discovering comps, sales history, photos, and more.'}, 'requestId': 2, 'cat1': {'searchResults': {'listResults': [{'zpid': '112520565', 'id': '112520565', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/93e24730c9241628af7d9bcd3a33fc56-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/93e24730c9241628af7d9bcd3a33fc56-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/9062-S-State-Route-48-Loveland-OH-45140/112520565_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$302,500', 'unformattedPrice': 302500, 'address': '9062 S State Route 48, Loveland, OH 45140', 'addressStreet': '9062 S State Route 48', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': 3, 'baths': 2.0, 'area': 0, 'latLong': {'latitude': 39.299713, 'longitude': -84.20989}, 'isZillowOwned': False, 'variableData': {'type': 'RECENTLY_SOLD', 'text': 'Sold 02/03/2023'}, 'badgeInfo': None, 'hdpData': {'homeInfo': {'zpid': 112520565, 'streetAddress': '9062 S State Route 48', 'zipcode': '45140', 'city': 'Loveland', 'state': 'OH', 'latitude': 39.299713, 'longitude': -84.20989, 'price': 302500.0, 'dateSold': 1675411200000, 'bathrooms': 2.0, 'bedrooms': 3.0, 'livingArea': 0.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'RECENTLY_SOLD', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'zestimate': 299600, 'rentZestimate': 1867, 'listing_sub_type': {}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'RECENTLY_SOLD', 'priceForHDP': 302500.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 15200.0, 'lotAreaValue': 1.29, 'lotAreaUnit': 'acres'}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'RecentlySold', 'sgapt': 'Unknown Listed By', 'zestimate': 299600, 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'info3String': 'https://photos.zillowstatic.com/fp/24a93a3e8104474bd1cf1ccae9e2ff31-zillow_web_48_23.jpg', 'brokerName': 'Keller Williams Pinnacle Group', 'hasAdditionalAttributions': True, 'isFeaturedListing': False, 'availabilityDate': None, 'list': True, 'relaxed': False}, {'zpid': '63496756', 'id': '63496756', 'providerListingId': None, 'streetViewMetadataURL': 'https://maps.googleapis.com/maps/api/streetview/metadata?location=39.23915481567383,-84.20394134521484&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=D5KCfvDKG1yjbtoy381Fh7EaxKs=', 'streetViewURL': 'https://maps.googleapis.com/maps/api/streetview?size=575x242&location=39.23915481567383,-84.20394134521484&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=lDChuXweeB3OeqAtmI9xiFlNd4o=', 'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=39.23915481567383,-84.20394134521484&k ...
# {'user': {'isLoggedIn': False, 'email': '', 'displayName': '', 'hasHousingConnectorPermission': False, 'savedHomesCount': 0, 'personalizedSearchGaDataTag': None, 'personalizedSearchTraceID': '6420f0d9544bd901afc9dd4ecc8a84ab', 'guid': '23d0665d-1a19-4c83-95e5-30ab8f8ec133', 'zuid': '', 'isBot': False, 'userSpecializedSEORegion': False}, 'mapState': {'customRegionPolygonWkt': None, 'schoolPolygonWkt': None, 'isCurrentLocationSearch': False, 'userPosition': {'lat': None, 'lon': None}}, 'regionState': {'regionInfo': [{'regionType': 6, 'regionId': 5710, 'regionName': 'Loveland', 'displayName': 'Loveland OH', 'isPointRegion': False}], 'regionBounds': {'north': 39.320723, 'east': -84.158661, 'south': 39.196881, 'west': -84.324107}}, 'searchPageSeoObject': {'baseUrl': '/loveland-oh/sold/4_p/', 'windowTitle': 'Recently Sold Homes in Loveland OH - 925 Transactions | Zillow', 'metaDescription': 'Browse data on the 925 recent real estate transactions in Loveland OH. Great for discovering comps, sales history, photos, and more.'}, 'requestId': 2, 'cat1': {'searchResults': {'listResults': [{'zpid': '110627150', 'id': '110627150', 'providerListingId': None, 'streetViewMetadataURL': 'https://maps.googleapis.com/maps/api/streetview/metadata?location=39.259090423583984,-84.25131225585938&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=uyQuGyzWaIHkpYl0H8EzxX29bJg=', 'streetViewURL': 'https://maps.googleapis.com/maps/api/streetview?size=575x242&location=39.259090423583984,-84.25131225585938&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=yXOf2OZK9A53ee2PBcZjqSZnt8A=', 'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=39.259090423583984,-84.25131225585938&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=kwFJqtmy2XJlE1-SsyGTBipT-i8=', 'carouselPhotos': None, 'detailUrl': 'https://www.zillow.com/homedetails/341-Ruth-Ave-Loveland-OH-45140/110627150_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$85,000', 'unformattedPrice': 85000, 'address': '341 Ruth Ave, Loveland, OH 45140', 'addressStreet': '341 Ruth Ave', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': 3, 'baths': 1.0, 'area': 792, 'latLong': {'latitude': 39.25909, 'longitude': -84.25131}, 'isZillowOwned': False, 'variableData': {'type': 'RECENTLY_SOLD', 'text': 'Sold 01/06/2023'}, 'badgeInfo': None, 'hdpData': {'homeInfo': {'zpid': 110627150, 'streetAddress': '341 Ruth Ave', 'zipcode': '45140', 'city': 'Loveland', 'state': 'OH', 'latitude': 39.25909, 'longitude': -84.25131, 'price': 85000.0, 'dateSold': 1672992000000, 'bathrooms': 1.0, 'bedrooms': 3.0, 'livingArea': 792.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'RECENTLY_SOLD', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'listing_sub_type': {}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'RECENTLY_SOLD', 'priceForHDP': 85000.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 3800.0, 'lotAreaValue': 4051.0, 'lotAreaUnit': 'sqft'}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'RecentlySold', 'sgapt': 'Unknown Listed By', 'zestimate': None, 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'hasAdditionalAttributions': False, 'isFeaturedListing': False, 'availabilityDate': None, 'list': True, 'relaxed': False}, {'zpid': '51267916', 'id': '51267916', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/f05342c966ea89d79117f1768e1b5140-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/f05342c966ea89d79117f1768e1b5140-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/1084-Tumbleweed-Dr-Loveland-OH-45140/51267916_zpid/', 'statusType': 'SOLD', 's ...
# {'user': {'isLoggedIn': False, 'email': '', 'displayName': '', 'hasHousingConnectorPermission': False, 'savedHomesCount': 0, 'personalizedSearchGaDataTag': None, 'personalizedSearchTraceID': '6420f1a140d53a4478d4450392163d8b', 'guid': '23d0665d-1a19-4c83-95e5-30ab8f8ec133', 'zuid': '', 'isBot': False, 'userSpecializedSEORegion': False}, 'mapState': {'customRegionPolygonWkt': None, 'schoolPolygonWkt': None, 'isCurrentLocationSearch': False, 'userPosition': {'lat': None, 'lon': None}}, 'regionState': {'regionInfo': [{'regionType': 6, 'regionId': 5710, 'regionName': 'Loveland', 'displayName': 'Loveland OH', 'isPointRegion': False}], 'regionBounds': {'north': 39.320723, 'east': -84.158661, 'south': 39.196881, 'west': -84.324107}}, 'searchPageSeoObject': {'baseUrl': '/loveland-oh/sold/5_p/', 'windowTitle': 'Recently Sold Homes in Loveland OH - 925 Transactions | Zillow', 'metaDescription': 'Browse data on the 925 recent real estate transactions in Loveland OH. Great for discovering comps, sales history, photos, and more.'}, 'requestId': 2, 'cat1': {'searchResults': {'listResults': [{'zpid': '51259224', 'id': '51259224', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/6f236a7ff804ed12872d97160208a4a3-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/6f236a7ff804ed12872d97160208a4a3-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/6612-Paxton-Guinea-Rd-Loveland-OH-45140/51259224_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$316,513', 'unformattedPrice': 316513, 'address': '6612 Paxton Guinea Rd, Loveland, OH 45140', 'addressStreet': '6612 Paxton Guinea Rd', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': 4, 'baths': 3.0, 'area': 2056, 'latLong': {'latitude': 39.228878, 'longitude': -84.24741}, 'isZillowOwned': False, 'variableData': {'type': 'RECENTLY_SOLD', 'text': 'Sold 12/09/2022'}, 'badgeInfo': None, 'hdpData': {'homeInfo': {'zpid': 51259224, 'streetAddress': '6612 Paxton Guinea Rd', 'zipcode': '45140', 'city': 'Loveland', 'state': 'OH', 'latitude': 39.228878, 'longitude': -84.24741, 'price': 316513.0, 'dateSold': 1670572800000, 'bathrooms': 3.0, 'bedrooms': 4.0, 'livingArea': 2056.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'RECENTLY_SOLD', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'zestimate': 320000, 'rentZestimate': 2394, 'listing_sub_type': {}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'RECENTLY_SOLD', 'priceForHDP': 316513.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 200800.0, 'lotAreaValue': 0.45999999999999996, 'lotAreaUnit': 'acres'}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'RecentlySold', 'sgapt': 'Unknown Listed By', 'zestimate': 320000, 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'info3String': 'https://photos.zillowstatic.com/fp/24a93a3e8104474bd1cf1ccae9e2ff31-zillow_web_48_23.jpg', 'brokerName': 'Keller Williams Pinnacle Group', 'hasAdditionalAttributions': True, 'isFeaturedListing': False, 'availabilityDate': None, 'list': True, 'relaxed': False}, {'zpid': '51264075', 'id': '51264075', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/658a05d7b5767cca122a56e5f5ad6ad8-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/658a05d7b5767cca122a56e5f5ad6ad8-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/6617-Paxton-Guinea-Rd-Loveland-OH-45140/51264075_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$205,000', 'unformattedPrice': 205000, 'address': '6617 Paxton Guinea Rd, Loveland, OH 45140', 'addressStreet': '6617 Paxton Guinea Rd', 'addressCity': 'Loveland', 'addre ...
# {'user': {'isLoggedIn': False, 'email': '', 'displayName': '', 'hasHousingConnectorPermission': False, 'savedHomesCount': 0, 'personalizedSearchGaDataTag': None, 'personalizedSearchTraceID': '6420f26a16e3305fce7bc1245c64a664', 'guid': '23d0665d-1a19-4c83-95e5-30ab8f8ec133', 'zuid': '', 'isBot': False, 'userSpecializedSEORegion': False}, 'mapState': {'customRegionPolygonWkt': None, 'schoolPolygonWkt': None, 'isCurrentLocationSearch': False, 'userPosition': {'lat': None, 'lon': None}}, 'regionState': {'regionInfo': [{'regionType': 6, 'regionId': 5710, 'regionName': 'Loveland', 'displayName': 'Loveland OH', 'isPointRegion': False}], 'regionBounds': {'north': 39.320723, 'east': -84.158661, 'south': 39.196881, 'west': -84.324107}}, 'searchPageSeoObject': {'baseUrl': '/loveland-oh/sold/6_p/', 'windowTitle': 'Recently Sold Homes in Loveland OH - 925 Transactions | Zillow', 'metaDescription': 'Browse data on the 925 recent real estate transactions in Loveland OH. Great for discovering comps, sales history, photos, and more.'}, 'requestId': 2, 'cat1': {'searchResults': {'listResults': [{'zpid': '34421291', 'id': '34421291', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/6682af876d3d1b97321df8c2665d6cd9-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/6682af876d3d1b97321df8c2665d6cd9-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/179-Glen-Lake-Rd-Loveland-OH-45140/34421291_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$350,000', 'unformattedPrice': 350000, 'address': '179 Glen Lake Rd, Loveland, OH 45140', 'addressStreet': '179 Glen Lake Rd', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': 4, 'baths': 3.0, 'area': 1890, 'latLong': {'latitude': 39.27044, 'longitude': -84.298454}, 'isZillowOwned': False, 'variableData': {'type': 'RECENTLY_SOLD', 'text': 'Sold 11/18/2022'}, 'badgeInfo': None, 'hdpData': {'homeInfo': {'zpid': 34421291, 'streetAddress': '179 Glen Lake Rd', 'zipcode': '45140', 'city': 'Loveland', 'state': 'OH', 'latitude': 39.27044, 'longitude': -84.298454, 'price': 350000.0, 'dateSold': 1668758400000, 'bathrooms': 3.0, 'bedrooms': 4.0, 'livingArea': 1890.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'RECENTLY_SOLD', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'zestimate': 355700, 'rentZestimate': 2299, 'listing_sub_type': {}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'RECENTLY_SOLD', 'priceForHDP': 350000.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 225000.0, 'lotAreaValue': 10802.88, 'lotAreaUnit': 'sqft'}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'RecentlySold', 'sgapt': 'Unknown Listed By', 'zestimate': 355700, 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'info3String': 'https://photos.zillowstatic.com/fp/24a93a3e8104474bd1cf1ccae9e2ff31-zillow_web_48_23.jpg', 'brokerName': 'eXp Realty', 'hasAdditionalAttributions': True, 'isFeaturedListing': False, 'availabilityDate': None, 'list': True, 'relaxed': False}, {'zpid': '51268069', 'id': '51268069', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/959eb28349a592103b01de6b82b38a0f-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/959eb28349a592103b01de6b82b38a0f-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/1513-Charleston-Ln-Loveland-OH-45140/51268069_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$400,000', 'unformattedPrice': 400000, 'address': '1513 Charleston Ln, Loveland, OH 45140', 'addressStreet': '1513 Charleston Ln', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddr ...
# {'user': {'isLoggedIn': False, 'email': '', 'displayName': '', 'hasHousingConnectorPermission': False, 'savedHomesCount': 0, 'personalizedSearchGaDataTag': None, 'personalizedSearchTraceID': '6420f333951cb5952b7420d885d5c6ff', 'guid': '23d0665d-1a19-4c83-95e5-30ab8f8ec133', 'zuid': '', 'isBot': False, 'userSpecializedSEORegion': False}, 'mapState': {'customRegionPolygonWkt': None, 'schoolPolygonWkt': None, 'isCurrentLocationSearch': False, 'userPosition': {'lat': None, 'lon': None}}, 'regionState': {'regionInfo': [{'regionType': 6, 'regionId': 5710, 'regionName': 'Loveland', 'displayName': 'Loveland OH', 'isPointRegion': False}], 'regionBounds': {'north': 39.320723, 'east': -84.158661, 'south': 39.196881, 'west': -84.324107}}, 'searchPageSeoObject': {'baseUrl': '/loveland-oh/sold/7_p/', 'windowTitle': 'Recently Sold Homes in Loveland OH - 925 Transactions | Zillow', 'metaDescription': 'Browse data on the 925 recent real estate transactions in Loveland OH. Great for discovering comps, sales history, photos, and more.'}, 'requestId': 2, 'cat1': {'searchResults': {'listResults': [{'zpid': '34420288', 'id': '34420288', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/b6642ea2a0038514c0549c3242ab8912-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/b6642ea2a0038514c0549c3242ab8912-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/1301-Sunrise-Dr-Loveland-OH-45140/34420288_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$148,600', 'unformattedPrice': 148600, 'address': '1301 Sunrise Dr, Loveland, OH 45140', 'addressStreet': '1301 Sunrise Dr', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': 3, 'baths': 1.0, 'area': 912, 'latLong': {'latitude': 39.267002, 'longitude': -84.276596}, 'isZillowOwned': False, 'variableData': {'type': 'RECENTLY_SOLD', 'text': 'Sold 11/02/2022'}, 'badgeInfo': None, 'hdpData': {'homeInfo': {'zpid': 34420288, 'streetAddress': '1301 Sunrise Dr', 'zipcode': '45140', 'city': 'Loveland', 'state': 'OH', 'latitude': 39.267002, 'longitude': -84.276596, 'price': 148600.0, 'dateSold': 1667372400000, 'bathrooms': 1.0, 'bedrooms': 3.0, 'livingArea': 912.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'RECENTLY_SOLD', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'zestimate': 140000, 'rentZestimate': 1650, 'listing_sub_type': {}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'RECENTLY_SOLD', 'priceForHDP': 148600.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 92530.0, 'lotAreaValue': 6185.52, 'lotAreaUnit': 'sqft'}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'RecentlySold', 'sgapt': 'Unknown Listed By', 'zestimate': 140000, 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'info3String': 'https://photos.zillowstatic.com/fp/24a93a3e8104474bd1cf1ccae9e2ff31-zillow_web_48_23.jpg', 'brokerName': 'Comey & Shepherd', 'hasAdditionalAttributions': True, 'isFeaturedListing': False, 'availabilityDate': None, 'list': True, 'relaxed': False}, {'zpid': '110618593', 'id': '110618593', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/7ee836490f25d75a1f3f79fb98be18ff-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/7ee836490f25d75a1f3f79fb98be18ff-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/29c3d484e2415bf409e873f00fabc884-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/28edaa27d82c5716148e48659f4a8f5c-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/e32af2eb8dc56db10e79440ea75fd476-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/78b208e7e946e481f5bba1fa63bbde8a-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/b887977ac80af ...
# {'user': {'isLoggedIn': False, 'email': '', 'displayName': '', 'hasHousingConnectorPermission': False, 'savedHomesCount': 0, 'personalizedSearchGaDataTag': None, 'personalizedSearchTraceID': '6420f3fb2bd76cf283edcb61f195c584', 'guid': '23d0665d-1a19-4c83-95e5-30ab8f8ec133', 'zuid': '', 'isBot': False, 'userSpecializedSEORegion': False}, 'mapState': {'customRegionPolygonWkt': None, 'schoolPolygonWkt': None, 'isCurrentLocationSearch': False, 'userPosition': {'lat': None, 'lon': None}}, 'regionState': {'regionInfo': [{'regionType': 6, 'regionId': 5710, 'regionName': 'Loveland', 'displayName': 'Loveland OH', 'isPointRegion': False}], 'regionBounds': {'north': 39.320723, 'east': -84.158661, 'south': 39.196881, 'west': -84.324107}}, 'searchPageSeoObject': {'baseUrl': '/loveland-oh/sold/8_p/', 'windowTitle': 'Recently Sold Homes in Loveland OH - 925 Transactions | Zillow', 'metaDescription': 'Browse data on the 925 recent real estate transactions in Loveland OH. Great for discovering comps, sales history, photos, and more.'}, 'requestId': 2, 'cat1': {'searchResults': {'listResults': [{'zpid': '112533274', 'id': '112533274', 'providerListingId': None, 'streetViewMetadataURL': 'https://maps.googleapis.com/maps/api/streetview/metadata?location=39.29934310913086,-84.25900268554688&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=A5xBEbIOIN5FZvutmFQLAu0kAv0=', 'streetViewURL': 'https://maps.googleapis.com/maps/api/streetview?size=575x242&location=39.29934310913086,-84.25900268554688&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=4y20OP4EbaK1CopEWZXTX9N24BI=', 'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=39.29934310913086,-84.25900268554688&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=kbdlMQh2gpoXCHZyyRW_BrNIwLU=', 'carouselPhotos': None, 'detailUrl': 'https://www.zillow.com/homedetails/Park-Ter-Loveland-OH-45140/112533274_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$10,000', 'unformattedPrice': 10000, 'address': 'Park Ter, Loveland, OH 45140', 'addressStreet': 'Park Ter', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': None, 'baths': None, 'area': None, 'latLong': {'latitude': 39.299343, 'longitude': -84.259}, 'isZillowOwned': False, 'variableData': {'type': 'RECENTLY_SOLD', 'text': 'Sold 10/21/2022'}, 'badgeInfo': None, 'hdpData': {'homeInfo': {'zpid': 112533274, 'streetAddress': 'Park Ter', 'zipcode': '45140', 'city': 'Loveland', 'state': 'OH', 'latitude': 39.299343, 'longitude': -84.259, 'price': 10000.0, 'dateSold': 1666335600000, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'RECENTLY_SOLD', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'listing_sub_type': {}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'RECENTLY_SOLD', 'priceForHDP': 10000.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 2360.0, 'lotAreaValue': 10075.0, 'lotAreaUnit': 'sqft'}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'RecentlySold', 'sgapt': 'Unknown Listed By', 'zestimate': None, 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'hasAdditionalAttributions': False, 'isFeaturedListing': False, 'availabilityDate': None, 'list': True, 'relaxed': False}, {'zpid': '2146367640', 'id': '2146367640', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/17307210e37d71482e87592cffaea186-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/17307210e37d71482e87592cffaea186-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/6667-Oakland-Rd-Loveland-OH-45140/2146367640_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$220,000', ...
# {'user': {'isLoggedIn': False, 'email': '', 'displayName': '', 'hasHousingConnectorPermission': False, 'savedHomesCount': 0, 'personalizedSearchGaDataTag': None, 'personalizedSearchTraceID': '6420f4c3474b7b82aa90c96b48dd15ad', 'guid': '23d0665d-1a19-4c83-95e5-30ab8f8ec133', 'zuid': '', 'isBot': False, 'userSpecializedSEORegion': False}, 'mapState': {'customRegionPolygonWkt': None, 'schoolPolygonWkt': None, 'isCurrentLocationSearch': False, 'userPosition': {'lat': None, 'lon': None}}, 'regionState': {'regionInfo': [{'regionType': 6, 'regionId': 5710, 'regionName': 'Loveland', 'displayName': 'Loveland OH', 'isPointRegion': False}], 'regionBounds': {'north': 39.320723, 'east': -84.158661, 'south': 39.196881, 'west': -84.324107}}, 'searchPageSeoObject': {'baseUrl': '/loveland-oh/sold/9_p/', 'windowTitle': 'Recently Sold Homes in Loveland OH - 925 Transactions | Zillow', 'metaDescription': 'Browse data on the 925 recent real estate transactions in Loveland OH. Great for discovering comps, sales history, photos, and more.'}, 'requestId': 2, 'cat1': {'searchResults': {'listResults': [{'zpid': '34419984', 'id': '34419984', 'providerListingId': None, 'streetViewMetadataURL': 'https://maps.googleapis.com/maps/api/streetview/metadata?location=39.268497467041016,-84.27346801757812&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=6n3K9yseWwMDXfgX335nEO7Uf4k=', 'streetViewURL': 'https://maps.googleapis.com/maps/api/streetview?size=575x242&location=39.268497467041016,-84.27346801757812&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=FcBo79dnpJhBlHbCKr22Cq2OmgU=', 'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=39.268497467041016,-84.27346801757812&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=bKEMDoPfywcc0HVUUPQ9_93w-NU=', 'carouselPhotos': None, 'detailUrl': 'https://www.zillow.com/homedetails/3-Pueblo-Ct-Loveland-OH-45140/34419984_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$135,000', 'unformattedPrice': 135000, 'address': '3 Pueblo Ct, Loveland, OH 45140', 'addressStreet': '3 Pueblo Ct', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': 3, 'baths': 1.0, 'area': 925, 'latLong': {'latitude': 39.268497, 'longitude': -84.27347}, 'isZillowOwned': False, 'variableData': {'type': 'RECENTLY_SOLD', 'text': 'Sold 10/04/2022'}, 'badgeInfo': None, 'hdpData': {'homeInfo': {'zpid': 34419984, 'streetAddress': '3 Pueblo Ct', 'zipcode': '45140', 'city': 'Loveland', 'state': 'OH', 'latitude': 39.268497, 'longitude': -84.27347, 'price': 135000.0, 'dateSold': 1664866800000, 'bathrooms': 1.0, 'bedrooms': 3.0, 'livingArea': 925.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'RECENTLY_SOLD', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'zestimate': 138400, 'rentZestimate': 1734, 'listing_sub_type': {}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'RECENTLY_SOLD', 'priceForHDP': 135000.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 96400.0, 'lotAreaValue': 9147.0, 'lotAreaUnit': 'sqft'}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'RecentlySold', 'sgapt': 'Unknown Listed By', 'zestimate': 138400, 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'hasAdditionalAttributions': False, 'isFeaturedListing': False, 'availabilityDate': None, 'list': True, 'relaxed': False}, {'zpid': '35633728', 'id': '35633728', 'providerListingId': None, 'streetViewMetadataURL': 'https://maps.googleapis.com/maps/api/streetview/metadata?location=39.28408432006836,-84.2325668334961&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=KQoJgPSAysUsLkRcPsXgoNEwGJw=', 'streetViewURL': 'https://maps.googleapis.com/maps/api/streetview?size=575x242&locat ...
# {'user': {'isLoggedIn': False, 'email': '', 'displayName': '', 'hasHousingConnectorPermission': False, 'savedHomesCount': 0, 'personalizedSearchGaDataTag': None, 'personalizedSearchTraceID': '6420f58c58724ce9e55a8c6f61757c4c', 'guid': '23d0665d-1a19-4c83-95e5-30ab8f8ec133', 'zuid': '', 'isBot': False, 'userSpecializedSEORegion': False}, 'mapState': {'customRegionPolygonWkt': None, 'schoolPolygonWkt': None, 'isCurrentLocationSearch': False, 'userPosition': {'lat': None, 'lon': None}}, 'regionState': {'regionInfo': [{'regionType': 6, 'regionId': 5710, 'regionName': 'Loveland', 'displayName': 'Loveland OH', 'isPointRegion': False}], 'regionBounds': {'north': 39.320723, 'east': -84.158661, 'south': 39.196881, 'west': -84.324107}}, 'searchPageSeoObject': {'baseUrl': '/loveland-oh/sold/10_p/', 'windowTitle': 'Recently Sold Homes in Loveland OH - 925 Transactions | Zillow', 'metaDescription': 'Browse data on the 925 recent real estate transactions in Loveland OH. Great for discovering comps, sales history, photos, and more.'}, 'requestId': 2, 'cat1': {'searchResults': {'listResults': [{'zpid': '51254818', 'id': '51254818', 'providerListingId': None, 'streetViewMetadataURL': 'https://maps.googleapis.com/maps/api/streetview/metadata?location=39.257781982421875,-84.2398681640625&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=_i4GdUKaWTHQXJfQijp9Yyp_gz4=', 'streetViewURL': 'https://maps.googleapis.com/maps/api/streetview?size=575x242&location=39.257781982421875,-84.2398681640625&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=4aG83ldsOFpfh4zUrjSaeJA6y3c=', 'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=39.257781982421875,-84.2398681640625&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=_Yh1Rjziphq1RyUPKDxTFHGXAJs=', 'carouselPhotos': None, 'detailUrl': 'https://www.zillow.com/homedetails/6670-State-Route-48-Loveland-OH-45140/51254818_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$255,000', 'unformattedPrice': 255000, 'address': '6670 State Route 48, Loveland, OH 45140', 'addressStreet': '6670 State Route 48', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': 3, 'baths': 1.5, 'area': 1680, 'latLong': {'latitude': 39.257782, 'longitude': -84.23987}, 'isZillowOwned': False, 'variableData': {'type': 'RECENTLY_SOLD', 'text': 'Sold 09/20/2022'}, 'badgeInfo': None, 'hdpData': {'homeInfo': {'zpid': 51254818, 'streetAddress': '6670 State Route 48', 'zipcode': '45140', 'city': 'Loveland', 'state': 'OH', 'latitude': 39.257782, 'longitude': -84.23987, 'price': 255000.0, 'dateSold': 1663657200000, 'bathrooms': 1.5, 'bedrooms': 3.0, 'livingArea': 1680.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'RECENTLY_SOLD', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'zestimate': 288800, 'rentZestimate': 1950, 'listing_sub_type': {}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'RECENTLY_SOLD', 'priceForHDP': 255000.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 143100.0, 'lotAreaValue': 0.9199954086317723, 'lotAreaUnit': 'acres'}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'RecentlySold', 'sgapt': 'Unknown Listed By', 'zestimate': 288800, 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'hasAdditionalAttributions': False, 'isFeaturedListing': False, 'availabilityDate': None, 'list': True, 'relaxed': False}, {'zpid': '2065452284', 'id': '2065452284', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/3f48ed713e97af6393953c9782667dcf-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/3f48ed713e97af6393953c9782667dcf-p_e.jpg'}], 'detailUrl': 'https://www.zillow ...
# {'user': {'isLoggedIn': False, 'email': '', 'displayName': '', 'hasHousingConnectorPermission': False, 'savedHomesCount': 0, 'personalizedSearchGaDataTag': None, 'personalizedSearchTraceID': '6420f65564deb35ade21fd2903b15c68', 'guid': '23d0665d-1a19-4c83-95e5-30ab8f8ec133', 'zuid': '', 'isBot': False, 'userSpecializedSEORegion': False}, 'mapState': {'customRegionPolygonWkt': None, 'schoolPolygonWkt': None, 'isCurrentLocationSearch': False, 'userPosition': {'lat': None, 'lon': None}}, 'regionState': {'regionInfo': [{'regionType': 6, 'regionId': 5710, 'regionName': 'Loveland', 'displayName': 'Loveland OH', 'isPointRegion': False}], 'regionBounds': {'north': 39.320723, 'east': -84.158661, 'south': 39.196881, 'west': -84.324107}}, 'searchPageSeoObject': {'baseUrl': '/loveland-oh/sold/11_p/', 'windowTitle': 'Recently Sold Homes in Loveland OH - 925 Transactions | Zillow', 'metaDescription': 'Browse data on the 925 recent real estate transactions in Loveland OH. Great for discovering comps, sales history, photos, and more.'}, 'requestId': 2, 'cat1': {'searchResults': {'listResults': [{'zpid': '34416149', 'id': '34416149', 'providerListingId': None, 'streetViewMetadataURL': 'https://maps.googleapis.com/maps/api/streetview/metadata?location=39.28875732421875,-84.28482818603516&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=cTju2UkRQMjzR9C0E6eoYPDLfvc=', 'streetViewURL': 'https://maps.googleapis.com/maps/api/streetview?size=575x242&location=39.28875732421875,-84.28482818603516&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=g77RZracgUe3QlqUGyLQwqiVLkA=', 'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=39.28875732421875,-84.28482818603516&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=HD2xELazk9czuRCge6Y6yQ1bh7s=', 'carouselPhotos': None, 'detailUrl': 'https://www.zillow.com/homedetails/9877-Fields-Ertel-Rd-Loveland-OH-45140/34416149_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$212,500', 'unformattedPrice': 212500, 'address': '9877 Fields Ertel Rd, Loveland, OH 45140', 'addressStreet': '9877 Fields Ertel Rd', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': 3, 'baths': 2.0, 'area': 1690, 'latLong': {'latitude': 39.288757, 'longitude': -84.28483}, 'isZillowOwned': False, 'variableData': {'type': 'RECENTLY_SOLD', 'text': 'Sold 09/08/2022'}, 'badgeInfo': None, 'hdpData': {'homeInfo': {'zpid': 34416149, 'streetAddress': '9877 Fields Ertel Rd', 'zipcode': '45140', 'city': 'Loveland', 'state': 'OH', 'latitude': 39.288757, 'longitude': -84.28483, 'price': 212500.0, 'dateSold': 1662620400000, 'bathrooms': 2.0, 'bedrooms': 3.0, 'livingArea': 1690.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'RECENTLY_SOLD', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'zestimate': 218800, 'rentZestimate': 2298, 'listing_sub_type': {}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'RECENTLY_SOLD', 'priceForHDP': 212500.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 224850.0, 'lotAreaValue': 1.9379935720844812, 'lotAreaUnit': 'acres'}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'RecentlySold', 'sgapt': 'Unknown Listed By', 'zestimate': 218800, 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'hasAdditionalAttributions': False, 'isFeaturedListing': False, 'availabilityDate': None, 'list': True, 'relaxed': False}, {'zpid': '34417710', 'id': '34417710', 'providerListingId': None, 'streetViewMetadataURL': 'https://maps.googleapis.com/maps/api/streetview/metadata?location=39.260250091552734,-84.30110168457031&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=aEVi02oYB1TAl1QDucvm_Ft3lts=', 'streetViewURL': 'https://maps.g ...
# ...
# {'user': {'isLoggedIn': False, 'email': '', 'displayName': '', 'hasHousingConnectorPermission': False, 'savedHomesCount': 0, 'personalizedSearchGaDataTag': None, 'personalizedSearchTraceID': '6420fbd034abf823c4322ba6a325c581', 'guid': '23d0665d-1a19-4c83-95e5-30ab8f8ec133', 'zuid': '', 'isBot': False, 'userSpecializedSEORegion': False}, 'mapState': {'customRegionPolygonWkt': None, 'schoolPolygonWkt': None, 'isCurrentLocationSearch': False, 'userPosition': {'lat': None, 'lon': None}}, 'regionState': {'regionInfo': [{'regionType': 6, 'regionId': 5710, 'regionName': 'Loveland', 'displayName': 'Loveland OH', 'isPointRegion': False}], 'regionBounds': {'north': 39.320723, 'east': -84.158661, 'south': 39.196881, 'west': -84.324107}}, 'searchPageSeoObject': {'baseUrl': '/loveland-oh/sold/18_p/', 'windowTitle': 'Recently Sold Homes in Loveland OH - 925 Transactions | Zillow', 'metaDescription': 'Browse data on the 925 recent real estate transactions in Loveland OH. Great for discovering comps, sales history, photos, and more.'}, 'requestId': 2, 'cat1': {'searchResults': {'listResults': [{'zpid': '2063239302', 'id': '2063239302', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/2c22ada47256f6f56a0bb648d7edba2f-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/2c22ada47256f6f56a0bb648d7edba2f-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/506-Wakefield-St-Loveland-OH-45140/2063239302_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$249,000', 'unformattedPrice': 249000, 'address': '506 Wakefield St, Loveland, OH 45140', 'addressStreet': '506 Wakefield St', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': 3, 'baths': 1.0, 'area': 1344, 'latLong': {'latitude': 39.260624, 'longitude': -84.2578}, 'isZillowOwned': False, 'variableData': {'type': 'RECENTLY_SOLD', 'text': 'Sold 06/22/2022'}, 'badgeInfo': None, 'hdpData': {'homeInfo': {'zpid': 2063239302, 'streetAddress': '506 Wakefield St', 'zipcode': '45140', 'city': 'Loveland', 'state': 'OH', 'latitude': 39.260624, 'longitude': -84.2578, 'price': 249000.0, 'dateSold': 1655881200000, 'bathrooms': 1.0, 'bedrooms': 3.0, 'livingArea': 1344.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'RECENTLY_SOLD', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'listing_sub_type': {}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'RECENTLY_SOLD', 'priceForHDP': 249000.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'lotAreaValue': 7405.2, 'lotAreaUnit': 'sqft'}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'RecentlySold', 'sgapt': 'Unknown Listed By', 'zestimate': None, 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'info3String': 'https://photos.zillowstatic.com/fp/24a93a3e8104474bd1cf1ccae9e2ff31-zillow_web_48_23.jpg', 'brokerName': 'Plum Tree Realty', 'hasAdditionalAttributions': True, 'isFeaturedListing': False, 'availabilityDate': None, 'list': True, 'relaxed': False}, {'zpid': '34415945', 'id': '34415945', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/6fde39d8f4afc56590b58ef9bdca8ff0-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/6fde39d8f4afc56590b58ef9bdca8ff0-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/12100-Rich-Rd-Loveland-OH-45140/34415945_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$335,000', 'unformattedPrice': 335000, 'address': '12100 Rich Rd, Loveland, OH 45140', 'addressStreet': '12100 Rich Rd', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': 3, 'baths': 2.0, 'area': 1713, 'latLong': {'latitude': 39.2 ...
# {'user': {'isLoggedIn': False, 'email': '', 'displayName': '', 'hasHousingConnectorPermission': False, 'savedHomesCount': 0, 'personalizedSearchGaDataTag': None, 'personalizedSearchTraceID': '6420fc9975454d4f78fe2deb76a9f79c', 'guid': '23d0665d-1a19-4c83-95e5-30ab8f8ec133', 'zuid': '', 'isBot': False, 'userSpecializedSEORegion': False}, 'mapState': {'customRegionPolygonWkt': None, 'schoolPolygonWkt': None, 'isCurrentLocationSearch': False, 'userPosition': {'lat': None, 'lon': None}}, 'regionState': {'regionInfo': [{'regionType': 6, 'regionId': 5710, 'regionName': 'Loveland', 'displayName': 'Loveland OH', 'isPointRegion': False}], 'regionBounds': {'north': 39.320723, 'east': -84.158661, 'south': 39.196881, 'west': -84.324107}}, 'searchPageSeoObject': {'baseUrl': '/loveland-oh/sold/19_p/', 'windowTitle': 'Recently Sold Homes in Loveland OH - 925 Transactions | Zillow', 'metaDescription': 'Browse data on the 925 recent real estate transactions in Loveland OH. Great for discovering comps, sales history, photos, and more.'}, 'requestId': 2, 'cat1': {'searchResults': {'listResults': [{'zpid': '35635385', 'id': '35635385', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/f87b2d2aa891674aeb6f09e9d8862eae-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/f87b2d2aa891674aeb6f09e9d8862eae-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/216-Sentry-Hill-Dr-Loveland-OH-45140/35635385_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$650,000', 'unformattedPrice': 650000, 'address': '216 Sentry Hill Dr, Loveland, OH 45140', 'addressStreet': '216 Sentry Hill Dr', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': 4, 'baths': 4.0, 'area': 3517, 'latLong': {'latitude': 39.271107, 'longitude': -84.251495}, 'isZillowOwned': False, 'variableData': {'type': 'RECENTLY_SOLD', 'text': 'Sold 06/10/2022'}, 'badgeInfo': None, 'hdpData': {'homeInfo': {'zpid': 35635385, 'streetAddress': '216 Sentry Hill Dr', 'zipcode': '45140', 'city': 'Loveland', 'state': 'OH', 'latitude': 39.271107, 'longitude': -84.251495, 'price': 650000.0, 'dateSold': 1654844400000, 'bathrooms': 4.0, 'bedrooms': 4.0, 'livingArea': 3517.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'RECENTLY_SOLD', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'zestimate': 684300, 'rentZestimate': 4067, 'listing_sub_type': {}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'RECENTLY_SOLD', 'priceForHDP': 650000.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 416090.0, 'lotAreaValue': 0.471, 'lotAreaUnit': 'acres'}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'RecentlySold', 'sgapt': 'Unknown Listed By', 'zestimate': 684300, 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'info3String': 'https://photos.zillowstatic.com/fp/24a93a3e8104474bd1cf1ccae9e2ff31-zillow_web_48_23.jpg', 'brokerName': 'Sibcy Cline, Inc.', 'hasAdditionalAttributions': True, 'isFeaturedListing': False, 'availabilityDate': None, 'list': True, 'relaxed': False}, {'zpid': '51257204', 'id': '51257204', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/8f2d25eed766e193afe4930255c9ee4b-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/8f2d25eed766e193afe4930255c9ee4b-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/6573-State-Route-48-Goshen-OH-45122/51257204_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$170,000', 'unformattedPrice': 170000, 'address': '6573 State Route 48, Goshen, OH 45122', 'addressStreet': '6573 State Route 48', 'addressCity': 'Goshen', 'addressState': 'OH', 'addressZipcode': '45122', 'isUn ...
# {'user': {'isLoggedIn': False, 'email': '', 'displayName': '', 'hasHousingConnectorPermission': False, 'savedHomesCount': 0, 'personalizedSearchGaDataTag': None, 'personalizedSearchTraceID': '6420fd62d3e9b6386b951f3972642946', 'guid': '23d0665d-1a19-4c83-95e5-30ab8f8ec133', 'zuid': '', 'isBot': False, 'userSpecializedSEORegion': False}, 'mapState': {'customRegionPolygonWkt': None, 'schoolPolygonWkt': None, 'isCurrentLocationSearch': False, 'userPosition': {'lat': None, 'lon': None}}, 'regionState': {'regionInfo': [{'regionType': 6, 'regionId': 5710, 'regionName': 'Loveland', 'displayName': 'Loveland OH', 'isPointRegion': False}], 'regionBounds': {'north': 39.320723, 'east': -84.158661, 'south': 39.196881, 'west': -84.324107}}, 'searchPageSeoObject': {'baseUrl': '/loveland-oh/sold/20_p/', 'windowTitle': 'Recently Sold Homes in Loveland OH - 925 Transactions | Zillow', 'metaDescription': 'Browse data on the 925 recent real estate transactions in Loveland OH. Great for discovering comps, sales history, photos, and more.'}, 'requestId': 2, 'cat1': {'searchResults': {'listResults': [{'zpid': '51261194', 'id': '51261194', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/ffa22ac39453df1370c75930749d781f-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/ffa22ac39453df1370c75930749d781f-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/6403-Roth-Ridge-Dr-Loveland-OH-45140/51261194_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$385,000', 'unformattedPrice': 385000, 'address': '6403 Roth Ridge Dr, Loveland, OH 45140', 'addressStreet': '6403 Roth Ridge Dr', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'isUndisclosedAddress': False, 'beds': 3, 'baths': 4.0, 'area': 2628, 'latLong': {'latitude': 39.22729, 'longitude': -84.241425}, 'isZillowOwned': False, 'variableData': {'type': 'RECENTLY_SOLD', 'text': 'Sold 05/27/2022'}, 'badgeInfo': None, 'hdpData': {'homeInfo': {'zpid': 51261194, 'streetAddress': '6403 Roth Ridge Dr', 'zipcode': '45140', 'city': 'Loveland', 'state': 'OH', 'latitude': 39.22729, 'longitude': -84.241425, 'price': 385000.0, 'dateSold': 1653634800000, 'bathrooms': 4.0, 'bedrooms': 3.0, 'livingArea': 2628.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'RECENTLY_SOLD', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'zestimate': 415400, 'rentZestimate': 2701, 'listing_sub_type': {}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'RECENTLY_SOLD', 'priceForHDP': 385000.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 277100.0, 'lotAreaValue': 0.48, 'lotAreaUnit': 'acres'}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'RecentlySold', 'sgapt': 'Unknown Listed By', 'zestimate': 415400, 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'info3String': 'https://photos.zillowstatic.com/fp/24a93a3e8104474bd1cf1ccae9e2ff31-zillow_web_48_23.jpg', 'brokerName': 'Comey & Shepherd', 'hasAdditionalAttributions': True, 'isFeaturedListing': False, 'availabilityDate': None, 'list': True, 'relaxed': False}, {'zpid': '58495901', 'id': '58495901', 'providerListingId': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/77e79cd6f7f7f304fd35656b6fbc7e3b-p_e.jpg', 'hasImage': True, 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/77e79cd6f7f7f304fd35656b6fbc7e3b-p_e.jpg'}], 'detailUrl': 'https://www.zillow.com/homedetails/2010-Collingwood-Ct-Loveland-OH-45140/58495901_zpid/', 'statusType': 'SOLD', 'statusText': 'Sold', 'countryCurrency': '$', 'soldPrice': '$255,000', 'unformattedPrice': 255000, 'address': '2010 Collingwood Ct, Loveland, OH 45140', 'addressStreet': '2010 Collingwood Ct', 'addressCity': 'Loveland', 'addressState': 'OH', 'addressZipcode': '45140', 'is ...

# %%
holder = (list(zip(statusType,soldPrice,unformattedPrice,address,addressStreet,addressCity,addressState,addressZipcode,beds,baths,area,isZillowOwned,variableData,hdpData,latitude,longitude,price,dateSold,homeType,homeStatus,zestimate,rentZestimate,priceForHDP,currency,country,taxAssessedValue,lotAreaValue,lotAreaUnit,brokerName)))
columns = ['statusType', 'soldPrice', 'unformattedPrice', 'address', 'addressStreet', 'addressCity', 'addressState', 'addressZipcode', 'beds', 'baths', 'area', 'isZillowOwned', 'variableData', 'hdpData', 'latitude', 'longitude', 'price', 'dateSold', 'homeType', 'homeStatus', 'zestimate', 'rentZestimate', 'priceForHDP', 'currency', 'country', 'taxAssessedValue', 'lotAreaValue', 'lotAreaUnit', 'brokerName']
houses = pd.DataFrame(holder, columns=columns)
houses.to_csv('houses.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis/Data Cleaning and Transformations

# %%
houses = pd.read_csv('houses.csv')
houses.head(2)
# Out:
#   statusType soldPrice  unformattedPrice  \
# 0       SOLD  $381,000            381000
# 1       SOLD  $627,500            627500
#
#                                   address       addressStreet addressCity  \
# 0       6533 Covey Ct, Loveland, OH 45140       6533 Covey Ct    Loveland
# 1  833 Miami Ridge Dr, Loveland, OH 45140  833 Miami Ridge Dr    Loveland
#
#   addressState  addressZipcode  beds  baths  ...     homeStatus  zestimate  \
# 0           OH           45140   3.0    3.0  ...  RECENTLY_SOLD   281500.0
# 1           OH           45140   4.0    4.0  ...  RECENTLY_SOLD        NaN
#
#   rentZestimate priceForHDP  currency  country  taxAssessedValue  \
# 0        2298.0    381000.0       USD      USA          192400.0
# 1           NaN    627500.0       USD      USA               NaN
#
#    lotAreaValue lotAreaUnit                      brokerName
# 0         0.920       acres  Keller Williams Pinnacle Group
# 1         0.459       acres  Keller Williams Pinnacle Group
#
# [2 rows x 29 columns]

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   statusType        840 non-null    object
#  1   soldPrice         840 non-null    object
#  2   unformattedPrice  840 non-null    int64
#  3   address           840 non-null    object
#  4   addressStreet     840 non-null    object
#  5   addressCity       840 non-null    object
#  6   addressState      840 non-null    object
#  7   addressZipcode    840 non-null    int64
#  8   beds              769 non-null    float64
#  9   baths             770 non-null    float64
#  10  area              768 non-null    float64
#  11  isZillowOwned     840 non-null    bool
#  12  variableData      840 non-null    object
#  13  hdpData           840 non-null    object
#  14  latitude          817 non-null    float64
#  15  longitude         817 non-null    float64
#  16  price             840 non-null    float64
#  17  dateSold          840 non-null    int64
#  18  homeType          840 non-null    object
#  19  homeStatus        840 non-null    object
#  20  zestimate         681 non-null    float64
#  21  rentZestimate     738 non-null    float64
#  22  priceForHDP       840 non-null    float64
#  23  currency          840 non-null    object
#  24  country           840 non-null    object
#  25  taxAssessedValue  790 non-null    float64
#  26  lotAreaValue      835 non-null    float64
#  27  lotAreaUnit       835 non-null    object
#  28  brokerName        566 non-null    object
# dtypes: bool(1), float64(11), int64(3), object(14)
# memory usage: 184.7+ KB

# %%
# Dropping some unuseful columns
houses.drop(['statusType', 'soldPrice', 'address', 'addressStreet', 'addressCity', 'addressState', 'addressZipcode', 'isZillowOwned', 'variableData', 'hdpData', 'price', 'homeType', 'homeStatus', 'priceForHDP', 'currency', 'country'], axis=1, inplace=True)

# %%
# Taking a look at the data again
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   unformattedPrice  840 non-null    int64
#  1   beds              769 non-null    float64
#  2   baths             770 non-null    float64
#  3   area              768 non-null    float64
#  4   latitude          817 non-null    float64
#  5   longitude         817 non-null    float64
#  6   dateSold          840 non-null    int64
#  7   zestimate         681 non-null    float64
#  8   rentZestimate     738 non-null    float64
#  9   taxAssessedValue  790 non-null    float64
#  10  lotAreaValue      835 non-null    float64
#  11  lotAreaUnit       835 non-null    object
#  12  brokerName        566 non-null    object
# dtypes: float64(9), int64(2), object(2)
# memory usage: 85.4+ KB

# %%
houses.drop(['brokerName', 'dateSold', 'taxAssessedValue'], axis=1, inplace=True)

# Changing column names to make more sense
houses.rename(columns={'unformattedPrice': 'price', 'area': 'sqft'}, inplace=True)

houses.head(2)
# Out:
#     price  beds  baths    sqft   latitude  longitude  zestimate  \
# 0  381000   3.0    3.0  1919.0  39.241352  -84.27033   281500.0
# 1  627500   4.0    4.0  3002.0  39.244730  -84.26501        NaN
#
#    rentZestimate  lotAreaValue lotAreaUnit
# 0         2298.0         0.920       acres
# 1            NaN         0.459       acres

# %%
houses.head(10)
# Out:
#     price  beds  baths    sqft   latitude  longitude  zestimate  \
# 0  381000   3.0    3.0  1919.0  39.241352  -84.27033   281500.0
# 1  627500   4.0    4.0  3002.0  39.244730  -84.26501        NaN
# 2  220000   3.0    1.0   962.0  39.262447  -84.27811        NaN
# 3  650000   5.0    4.0  4488.0  39.266975  -84.28734   680000.0
# 4  460000   4.0    4.0  4470.0  39.226704  -84.25058   518000.0
# 5  223000   3.0    1.0  1069.0  39.261356  -84.27919   229500.0
# 6  226250   3.0    1.0  1206.0  39.275352  -84.29681   212800.0
# 7  377000   3.0    3.0  1643.0  39.300100  -84.29534   380200.0
# 8  299900   2.0    1.0     0.0  39.274650  -84.19473   297600.0
# 9  412500   4.0    4.0  2104.0  39.242960  -84.21550   378200.0
#
#    rentZestimate  lotAreaValue lotAreaUnit
# 0         2298.0        0.9200       acres
# 1            NaN        0.4590       acres
# 2         1745.0     7797.2400        sqft
# 3         4627.0        0.4380       acres
# 4         3358.0        0.4400       acres
# 5         1783.0     7187.4000        sqft
# 6         1800.0        0.2770       acres
# 7         2088.0        0.3022       acres
# 8         1625.0        2.0000       acres
# 9         2368.0        0.4810       acres

# %%
# Some of the area values are in sqft and some are in acres, let's convert all of them to acres
def convert_to_acres(row):
    if row['lotAreaUnit'] == 'sqft':
        return row['lotAreaValue'] / 43560
    else:
        return row['lotAreaValue']

houses['lotAreaValue'] = houses.apply(convert_to_acres, axis=1)

houses.head(10)
# Out:
#     price  beds  baths    sqft   latitude  longitude  zestimate  \
# 0  381000   3.0    3.0  1919.0  39.241352  -84.27033   281500.0
# 1  627500   4.0    4.0  3002.0  39.244730  -84.26501        NaN
# 2  220000   3.0    1.0   962.0  39.262447  -84.27811        NaN
# 3  650000   5.0    4.0  4488.0  39.266975  -84.28734   680000.0
# 4  460000   4.0    4.0  4470.0  39.226704  -84.25058   518000.0
# 5  223000   3.0    1.0  1069.0  39.261356  -84.27919   229500.0
# 6  226250   3.0    1.0  1206.0  39.275352  -84.29681   212800.0
# 7  377000   3.0    3.0  1643.0  39.300100  -84.29534   380200.0
# 8  299900   2.0    1.0     0.0  39.274650  -84.19473   297600.0
# 9  412500   4.0    4.0  2104.0  39.242960  -84.21550   378200.0
#
#    rentZestimate  lotAreaValue lotAreaUnit
# 0         2298.0        0.9200       acres
# 1            NaN        0.4590       acres
# 2         1745.0        0.1790        sqft
# 3         4627.0        0.4380       acres
# 4         3358.0        0.4400       acres
# 5         1783.0        0.1650        sqft
# 6         1800.0        0.2770       acres
# 7         2088.0        0.3022       acres
# 8         1625.0        2.0000       acres
# 9         2368.0        0.4810       acres

# %%
houses.drop(['lotAreaUnit'], axis=1, inplace=True)

# %%
# Check for duplicates
houses.duplicated().sum()
# Out:
# 42

# %%
# Looks like there are duplicates, some of the initial houses were repeated
houses[houses.duplicated()]
# Out:
#       price  beds  baths    sqft   latitude  longitude  zestimate  \
# 40   381000   3.0    3.0  1919.0  39.241352 -84.270330   281500.0
# 41   627500   4.0    4.0  3002.0  39.244730 -84.265010        NaN
# 42   220000   3.0    1.0   962.0  39.262447 -84.278110        NaN
# 43   650000   5.0    4.0  4488.0  39.266975 -84.287340   680000.0
# 44   460000   4.0    4.0  4470.0  39.226704 -84.250580   518000.0
# 45   223000   3.0    1.0  1069.0  39.261356 -84.279190   229500.0
# 46   226250   3.0    1.0  1206.0  39.275352 -84.296810   212800.0
# 47   377000   3.0    3.0  1643.0  39.300100 -84.295340   380200.0
# 48   299900   2.0    1.0     0.0  39.274650 -84.194730   297600.0
# 49   412500   4.0    4.0  2104.0  39.242960 -84.215500   378200.0
# 50   252000   3.0    3.0  1426.0  39.210140 -84.189900   250800.0
# 51   489900   4.0    4.0  3502.0  39.281357 -84.245060   494700.0
# 52   484000   4.0    3.0  2788.0        NaN        NaN        NaN
# 53   427000   4.0    4.0  3605.0  39.259243 -84.287050   427100.0
# 54   194000   2.0    1.0  1214.0  39.304650 -84.262180   194100.0
# 55   580000   5.0    4.0  3755.0  39.298850 -84.278970   580400.0
# 56   125000   2.0    1.0  1389.0  39.258816 -84.253555   291400.0
# 57   595000   4.0    6.0  3252.0  39.288532 -84.287544   595300.0
# 58   430000   3.0    2.0  1844.0  39.239452 -84.245620   430200.0
# 59   335000   3.0    3.0  1734.0  39.206840 -84.226030   335100.0
# 60   435000   4.0    4.0  2647.0  39.239746 -84.274734   435500.0
# 61   270000   3.0    2.0  1652.0  39.243650 -84.218124   298000.0
# 62   429000   3.0    4.0  2801.0  39.232200 -84.249040   429400.0
# 63   250000   3.0    1.0   999.0  39.263283 -84.278046   250100.0
# 64   815000   6.0    5.0  5189.0  39.287940 -84.287780   815200.0
# 65   243000   4.0    2.0  1436.0  39.236214 -84.202100   243200.0
# 66   409500   4.0    3.0  2492.0  39.207462 -84.226974   410000.0
# 67   180000   3.0    1.5  1000.0  39.305275 -84.261300   230000.0
# 68   820000   4.0    4.0     0.0  39.295820 -84.270580   820800.0
# 69   656644   3.0    3.0  2215.0  39.265488 -84.257870   657700.0
# 70   290000   3.0    2.0   946.0  39.306114 -84.263800   291100.0
# 71   695000   4.0    5.0  4436.0  39.250190 -84.270355   697100.0
# 72   305000   4.0    3.0  1780.0  39.206880 -84.188410   306100.0
# 73   157370   3.0    2.0  1440.0  39.233753 -84.198380   139500.0
# 74   244500   3.0    2.5  2086.0  39.220978 -84.193000        NaN
# 75   539750   4.0    4.0  3174.0  39.239270 -84.255394   540500.0
# 76   690000   3.0    3.0  3651.0  39.298320 -84.267960   692900.0
# 77   595602   NaN    NaN     NaN  39.241300 -84.289080        NaN
# 78   681500   4.0    3.0     0.0  39.301440 -84.265980        NaN
# 79   483000   4.0    3.0  2472.0  39.237892 -84.306660   483000.0
# 160   85000   3.0    1.0   792.0  39.259090 -84.251310        NaN
# 680  155000   NaN    NaN     NaN  39.212006 -84.300090        NaN
#
#      rentZestimate  lotAreaValue
# 40          2298.0      0.920000
# 41             NaN      0.459000
# 42          1745.0      0.179000
# 43          4627.0      0.438000
# 44          3358.0      0.440000
# 45          1783.0      0.165000
# 46          1800.0      0.277000
# 47          2088.0      0.302200
# 48          1625.0      2.000000
# 49          2368.0      0.481000
# 50          1798.0      0.110000
# 51          3200.0      0.214100
# 52          2736.0      0.267500
# 53          3138.0      0.301000
# 54          1688.0      0.280000
# 55          3707.0      0.523200
# 56          2061.0      0.573990
# 57          4237.0      0.508000
# 58          2846.0      0.324000
# 59          1852.0      0.216000
# 60          2943.0      0.488000
# 61          1825.0      0.589991
# 62          2843.0      0.294000
# 63          1747.0      0.241000
# 64          4941.0      0.546000
# 65          1800.0      0.620000
# 66          2492.0      0.220000
# 67          1617.0      0.446602
# 68          4883.0      0.305300
# 69          4037.0      0.050000
# 70          1674.0      0.139000
# 71          4663.0      0.459000
# 72          1820.0      0.247000
# 73          1862.0      0.376000
# 74          1200.0      0.055992
# 75          3606.0      0.230000
# 76          3761.0      0.160400
# 77             NaN      0.364991
# 78             NaN      0.353000
# 79          3198.0      0.943000
# 160            NaN      0.092998
# 680            NaN      0.114991

# %%
houses.drop_duplicates(inplace=True)
houses.duplicated().sum()
# Out:
# 0

# %%
houses.isna().sum()
# Out:
# price              0
# beds              69
# baths             68
# sqft              70
# latitude          22
# longitude         22
# zestimate        151
# rentZestimate     97
# lotAreaValue       5
# dtype: int64

# %%
houses.drop(['zestimate', 'rentZestimate'], axis=1, inplace=True)

# %%
print(houses[houses.isna().any(axis=1)])
# Out:
#         price  beds  baths     sqft   latitude  longitude  lotAreaValue
# 12     484000   4.0    3.0   2788.0        NaN        NaN      0.267500
# 37     595602   NaN    NaN      NaN  39.241300 -84.289080      0.364991
# 84     481000   4.0    4.0      NaN  39.214912 -84.233020      0.239991
# 101    470000   4.0    3.0   2680.0        NaN        NaN      0.333000
# 103    200000   NaN    NaN      NaN  39.279680 -84.199410     29.402181
# 107    700000   NaN    NaN      NaN  39.299442 -84.278755      0.362994
# 110    210000   NaN    NaN      NaN  39.301580 -84.288700      0.005716
# 111    550000   NaN    NaN      NaN  39.205920 -84.218250      1.009986
# 112    610578   3.0    3.0      0.0        NaN        NaN      0.550000
# 114     85000   NaN    NaN      NaN  39.245243 -84.212370      0.504982
# 115     85000   NaN    NaN      NaN  39.245330 -84.212470      0.659986
# 125    185000   3.0    1.0   1418.0        NaN        NaN      0.241001
# 132    239000   NaN    NaN      NaN  39.301758 -84.288430      0.005785
# 135     15000   NaN    NaN      NaN  39.252050 -84.286020      0.055992
# 136     15000   NaN    NaN      NaN  39.252490 -84.285950      0.056979
# 137    530000   NaN    NaN      NaN  39.278744 -84.266770      1.075000
# 138     15000   NaN    NaN      NaN  39.252068 -84.285940      0.062994
# 187    483000   4.0    3.0   2232.0        NaN        NaN      0.524000
# 210    517000   NaN    NaN      NaN  39.274372 -84.274790      0.094995
# 219    719900   4.0    4.0      0.0        NaN        NaN      0.632000
# 220   1222500   4.0    5.0      0.0        NaN        NaN      0.430000
# 223   1088000   NaN    NaN      NaN  39.231090 -84.266650      0.510996
# 238    259900   3.0    3.0   1460.0        NaN        NaN      0.230005
# 242   1088000   4.0    4.0      0.0        NaN        NaN      0.510900
# 254     90000   NaN    NaN      NaN  39.286710 -84.266030      0.606589
# 266    100000   3.0    1.0   1056.0  39.244717 -84.294650           NaN
# 293     85000   NaN    NaN      NaN  39.247303 -84.211370      0.484986
# 294     85000   NaN    NaN      NaN  39.245300 -84.212430      0.645983
# 302     75000   NaN    NaN      NaN  39.252440 -84.286120      0.056979
# 320     10000   NaN    NaN      NaN  39.299343 -84.259000      0.231290
# 339   1299257   NaN    NaN      NaN  39.229992 -84.317410      1.342998
# 346    340000   3.0    2.5   2497.0  39.244736 -84.216194           NaN
# 347   5300000   NaN    NaN      NaN        NaN        NaN           NaN
# 355    620000   NaN    NaN      NaN  39.284534 -84.270710      0.667998
# 373    160000   NaN    NaN      NaN  39.211514 -84.303590      0.114991
# 374   1435479   4.0    4.0      0.0        NaN        NaN      0.480000
# 380   1299257   5.0    5.0      0.0        NaN        NaN      1.343000
# 392    160000   4.0    2.0   2008.0        NaN        NaN      0.114800
# 393    458000   4.0    3.0      0.0        NaN        NaN      2.660000
# 397    538830   NaN    NaN      NaN  39.214035 -84.234276      0.538981
# 401   1299000   4.0    4.0      0.0        NaN        NaN      0.380000
# 403    224000   NaN    NaN      NaN  39.260624 -84.251080      0.021993
# 404    224000   NaN    NaN      NaN  39.289165 -84.265390      0.092080
# 405      6100   NaN    NaN      NaN  39.302990 -84.259790      0.091827
# 462    103100   NaN    NaN      NaN  39.290460 -84.265340      0.002686
# 482    286000   NaN    NaN      NaN  39.304417 -84.268270      0.046786
# 492    700000   3.0    3.0      NaN  39.296650 -84.268270      0.218182
# 493    560000   3.0    2.0   2403.0        NaN        NaN      0.251400
# 500     25000   NaN    NaN      NaN  39.272960 -84.250930      0.523990
# 505    682475   NaN    NaN      NaN  39.264675 -84.221730      5.061983
# 506    375681   NaN    NaN      NaN  39.206370 -84.177635      2.151997
# 516    481205   NaN    NaN      NaN  39.216545 -84.235600      0.428994
# 517    630000   3.0    3.0      0.0        NaN        NaN      3.853000
# 525    475000   NaN    3.0   1686.0  39.277798 -84.283710      0.150987
# 526   1695246   NaN    NaN      NaN  39.232080 -84.316290      1.561983
# 539     85000   NaN    NaN      NaN  39.246773 -84.210740      0.486983
# 540      1000   NaN    NaN      NaN  39.260624 -84.251080      0.092172
# 553     60000   NaN    NaN      NaN  39.297870 -84.224724      1.016988
# 559    285000   NaN    NaN      NaN  39.309070 -84.268290      0.138935
# 573   1550000   NaN    NaN      NaN  39.287247 -84.239330      2.572980
# 574   1550000   3.0    2.5      NaN  39.287247 -84.239330      0.358999
# 585     31000   NaN    NaN      NaN  39.300877 -84.278110      0.573921
# 586     31000   NaN    NaN      NaN  39.300877 -84.278110      0.395960
# 587     31000   NaN    NaN      NaN  39.288933 -84.266136      0.189394
# 590    655375   NaN    NaN      NaN  39.213990 -84.234710      0.429982
# 591   1695246   4.0    5.0      0.0        NaN        NaN      1.091600
# 604    501447   NaN    NaN      NaN  39.241196 -84.288470      0.302984
# 624    442000   NaN    NaN      NaN  39.216480 -84.233086      0.235996
# 627    442000   4.0    4.0      0.0        NaN        NaN      0.236000
# 637    140000   NaN    NaN      NaN  39.212093 -84.298600      0.015978
# 638    140000   NaN    NaN      NaN  39.212543 -84.298750      0.098990
# 654    544125   NaN    NaN      NaN  39.213787 -84.233860      0.450000
# 658    130000   NaN    NaN      NaN  39.224686 -84.306030      0.129982
# 660    125000   NaN    NaN      NaN  39.211514 -84.303590      0.114991
# 661    125000   NaN    NaN      NaN  39.212658 -84.297935      0.114991
# 665    196000   3.0    1.0      0.0  39.261112 -84.260414           NaN
# 676    155000   NaN    NaN      NaN  39.211514 -84.303590      0.029982
# 677    155000   NaN    NaN      NaN  39.212006 -84.300090      0.019995
# 679    155000   NaN    NaN      NaN  39.212006 -84.300090      0.114991
# 689    501447   2.0    2.0      0.0        NaN        NaN      0.300000
# 692  10326000   NaN    NaN      NaN  39.222290 -84.286400      7.489991
# 693     87000   NaN    NaN      NaN  39.252770 -84.285990      0.056979
# 705    200000   NaN    NaN      NaN  39.271824 -84.255830      0.025781
# 716     85000   NaN    NaN      NaN  39.245396 -84.212550      0.687994
# 718    235000   NaN    NaN      NaN  39.265965 -84.255480      0.028994
# 719    235000   NaN    NaN      NaN  39.265965 -84.255480      0.056979
# 737    153000   NaN    NaN      NaN  39.252842 -84.285736      0.056979
# 741    250000   3.0    1.0   1172.0        NaN        NaN      0.460000
# 765    642324   NaN    NaN      NaN  39.295242 -84.269646      0.188177
# 766   3100000   NaN    NaN      NaN  39.292530 -84.245950     23.999885
# 775      9500   NaN    NaN      NaN  39.288834 -84.267365      0.236731
# 777    106000   3.0    1.0      NaN  39.213104 -84.300430      0.343985
# 783    494745   NaN    NaN      NaN  39.213924 -84.234300      0.648990
# 795   3100000   6.0    8.0      0.0  39.292530 -84.245950           NaN
# 805    650000   4.0    4.0   2791.0        NaN        NaN      0.307700
# 833   1609200   NaN    NaN  18748.0  39.245260 -84.293120      0.635996
# 834   1609200   NaN    NaN   6000.0  39.230755 -84.259200      1.323990
# 839    270000   NaN    NaN      NaN  39.278520 -84.283646      0.015978

# %%
houses.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'beds'}>,
#         <Axes: title={'center': 'baths'}>],
#        [<Axes: title={'center': 'sqft'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'longitude'}>],
#        [<Axes: title={'center': 'lotAreaValue'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# Remove the record if it doesn't have the number of bedrooms
houses.dropna(subset=['beds'], inplace=True)
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 729 entries, 0 to 838
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         729 non-null    int64
#  1   beds          729 non-null    float64
#  2   baths         729 non-null    float64
#  3   sqft          725 non-null    float64
#  4   latitude      708 non-null    float64
#  5   longitude     708 non-null    float64
#  6   lotAreaValue  725 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 45.6 KB

# %%
# Going to remove the remaning records with missing values
houses.dropna(subset=['latitude', 'longitude', 'sqft', 'lotAreaValue'], inplace=True)
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 700 entries, 0 to 838
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         700 non-null    int64
#  1   beds          700 non-null    float64
#  2   baths         700 non-null    float64
#  3   sqft          700 non-null    float64
#  4   latitude      700 non-null    float64
#  5   longitude     700 non-null    float64
#  6   lotAreaValue  700 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 43.8 KB

# %%
houses.describe()
# Out:
#               price        beds       baths         sqft    latitude  \
# count  7.000000e+02  700.000000  700.000000   700.000000  700.000000
# mean   3.931400e+05    3.432857    2.697857  2143.772857   39.255046
# std    2.932837e+05    0.780525    1.223194  1087.326998    0.028205
# min    1.000000e+03    1.000000    0.500000     0.000000   39.202602
# 25%    2.300000e+05    3.000000    2.000000  1388.000000   39.232415
# 50%    3.390000e+05    3.000000    3.000000  1915.500000   39.258232
# 75%    4.930280e+05    4.000000    3.500000  2789.750000   39.274215
# max    5.300000e+06    7.000000    7.000000  6330.000000   39.309097
#
#         longitude  lotAreaValue
# count  700.000000    700.000000
# mean   -84.255527      0.793581
# std      0.036055      2.359147
# min    -84.318184      0.012900
# 25%    -84.283531      0.229600
# 50%    -84.262581      0.444801
# 75%    -84.231943      0.607231
# max    -84.159485     48.000000

# %%
houses["price"].plot.hist(bins=50, figsize=(10,5))
plt.show()

# %%
fig = go.Figure(data=go.Scattergeo(
        lon = houses['longitude'],
        lat = houses['latitude'],
        mode = 'markers'
        ))

fig.update_layout(
        title = 'Housing Data in Loveland, OH',
        geo_scope='usa'
    )

fig.show()

# %%
# Correlation data for the price
houses.corr()['price'].sort_values(ascending=False)
# Out:
# price           1.000000
# baths           0.532495
# sqft            0.531244
# beds            0.395425
# lotAreaValue    0.233207
# latitude        0.032056
# longitude      -0.065008
# Name: price, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(6,6))
sns.heatmap(houses.corr(), annot=True, ax=ax)
# Out:
# <Axes: >

# %%
sns.scatterplot(x='sqft', y='price', data=houses)
# Out:
# <Axes: xlabel='sqft', ylabel='price'>

# %%
sns.scatterplot(x='lotAreaValue', y='price', data=houses)
# Out:
# <Axes: xlabel='lotAreaValue', ylabel='price'>

# %%
sns.scatterplot(x='beds', y='price', data=houses)
# Out:
# <Axes: xlabel='beds', ylabel='price'>

# %%
sns.scatterplot(x='baths', y='price', data=houses)
# Out:
# <Axes: xlabel='baths', ylabel='price'>

# %% [markdown]
# ## Resources and References
# *What resources and references have you used for this project?*
# 📝 <!-- Answer Below -->

# %%
# ⚠️ Make sure you run this cell at the end of your notebook before every submission!
# !jupyter nbconvert --to python LovelandHousing.ipynb
# Out:
# [NbConvertApp] Converting notebook LovelandHousing.ipynb to python
# [NbConvertApp] Writing 17379 bytes to LovelandHousing.py
